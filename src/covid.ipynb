# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1) Обоснование данных

# %%
data = pd.read_csv('covid_19_2022.csv', index_col=False)
data
# Out:
#        Province/State        Country/Region        Lat        Long  \
# 0                 NaN           Afghanistan  33.939110   67.709953
# 1                 NaN               Albania  41.153300   20.168300
# 2                 NaN               Algeria  28.033900    1.659600
# 3                 NaN               Andorra  42.506300    1.521800
# 4                 NaN                Angola -11.202700   17.873900
# ...               ...                   ...        ...         ...
# 214889            NaN    West Bank and Gaza  31.952200   35.233200
# 214890            NaN  Winter Olympics 2022  39.904200  116.407400
# 214891            NaN                 Yemen  15.552727   48.516388
# 214892            NaN                Zambia -13.133897   27.849332
# 214893            NaN              Zimbabwe -19.015438   29.154857
#
#               Date  Confirmed  Deaths  Recovered  Active  \
# 0       2020-01-22          0       0          0       0
# 1       2020-01-22          0       0          0       0
# 2       2020-01-22          0       0          0       0
# 3       2020-01-22          0       0          0       0
# 4       2020-01-22          0       0          0       0
# ...            ...        ...     ...        ...     ...
# 214889  2022-03-04     649971    5557          0  644414
# 214890  2022-03-04        530       0          0     530
# 214891  2022-03-04      11774    2135          0    9639
# 214892  2022-03-04     313613    3958          0  309655
# 214893  2022-03-04     238739    5397          0  233342
#
#                    WHO Region
# 0       Eastern Mediterranean
# 1                      Europe
# 2                      Africa
# 3                      Europe
# 4                      Africa
# ...                       ...
# 214889  Eastern Mediterranean
# 214890                    NaN
# 214891  Eastern Mediterranean
# 214892                 Africa
# 214893                 Africa
#
# [214894 rows x 10 columns]

# %% [markdown]
# <p>Новый коронавирус, получивший обозначение 2019-nCoV, был впервые выявлен в Ухане, столице китайской провинции Хубэй.<br>
# У людей развилась пневмония без ясной причины, для которой существующие вакцины или методы лечения оказались неэффективными..<br>
# Вирус показал доказательства передачи от человека к человеку.<br>
# Скорость передачи (уровень заражения), по-видимому, увеличилась в середине января 2020 г..<br>
# По состоянию на 30 января 2020 г. было подтверждено около 8 243 случаев..<br>
# Во время пандемии очень важно следить за статистикой, она помагает выявлять неочевидные закономернности, тем самым спасая множество жизней.<br>
# С помощью этих данных мы можем контролировать развитие вируса и предотвращать опасности.</p>

# %% [markdown]
# ### 2) Элементарные статистики

# %% [markdown]
# <p>Сразу видно, что в данных есть пропущенные значения</p>

# %%
print(data.isnull().sum())
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64

# %%
data = data.dropna()
print(data.isnull().sum())
data
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64
#                       Province/State  Country/Region        Lat        Long  \
# 9       Australian Capital Territory       Australia -35.473500  149.012400
# 10                   New South Wales       Australia -33.868800  151.209300
# 11                Northern Territory       Australia -12.463400  130.845600
# 12                        Queensland       Australia -27.469800  153.025100
# 13                   South Australia       Australia -34.928500  138.600700
# ...                              ...             ...        ...         ...
# 214878                      Guernsey  United Kingdom  49.448196   -2.589490
# 214879                   Isle of Man  United Kingdom  54.236100   -4.548100
# 214880                        Jersey  United Kingdom  49.213800   -2.135800
# 214881                    Montserrat  United Kingdom  16.742498  -62.187366
# 214882      Turks and Caicos Islands  United Kingdom  21.694000  -71.797900
#
#               Date  Confirmed  Deaths  Recovered  Active       WHO Region
# 9       2020-01-22          0       0          0       0  Western Pacific
# 10      2020-01-22          0       0          0       0  Western Pacific
# 11      2020-01-22          0       0          0       0  Western Pacific
# 12      2020-01-22          0       0          0       0  Western Pacific
# 13      2020-01-22          0       0          0       0  Western Pacific
# ...            ...        ...     ...        ...     ...              ...
# 214878  2022-03-04      14434      31          0   14403           Europe
# 214879  2022-03-04      23328      80          0   23248           Europe
# 214880  2022-03-04      38480     113          0   38367           Europe
# 214881  2022-03-04        164       2          0     162           Europe
# 214882  2022-03-04       5867      36          0    5831           Europe
#
# [64159 rows x 10 columns]

# %% [markdown]
# <p>Посмотрим какой тип данных хранится в каждом признаке</p>

# %% [markdown]
# <p>Найдем категориальные и числовые признаки (часть индивидуального задания)</p>

# %%
columns_numeric = data.select_dtypes(include=['float64', 'int64']).columns
columns_categorical = data.select_dtypes(include='object').columns

# %% [markdown]
# <p>Найдем максимум среди числовых признаков</p>

# %%
data[columns_numeric].max()
# Out:
# Lat          7.170690e+01
# Long         1.656180e+02
# Confirmed    1.361680e+06
# Deaths       1.405600e+04
# Recovered    6.443500e+04
# Active       1.359744e+06
# dtype: float64

# %% [markdown]
# <p>Найдем минимум среди числовых признаков</p>

# %%
data[columns_numeric].min()
# Out:
# Lat           -51.7963
# Long         -178.1165
# Confirmed       0.0000
# Deaths          0.0000
# Recovered       0.0000
# Active      -8322.0000
# dtype: float64

# %% [markdown]
# <p>Найдем среднее среди числовых признаков</p>

# %%
data[columns_numeric].mean()
# Out:
# Lat             24.537150
# Long            31.341850
# Confirmed    17508.427360
# Deaths         305.506866
# Recovered     1186.254041
# Active       16016.666454
# dtype: float64

# %% [markdown]
# <p>Найдем медиану среди числовых признаков</p>

# %%
data[columns_numeric].median()
# Out:
# Lat           30.9756
# Long          88.0924
# Confirmed    618.0000
# Deaths         3.0000
# Recovered      3.0000
# Active        55.0000
# dtype: float64

# %% [markdown]
# <p>Найдем Standard deviation среди числовых признаков</p>

# %%
data[columns_numeric].std()
# Out:
# Lat             28.537223
# Long            97.901982
# Confirmed    82136.386229
# Deaths        1370.871180
# Recovered     6094.749701
# Active       81084.610973
# dtype: float64

# %% [markdown]
# <p>Также в pandas есть вспомогательная функция, с помощью которой можно одной строчкой подсчитать элементарные статистики</p>

# %%
data.describe(include='all')
# Out:
#                       Province/State Country/Region           Lat  \
# count                          64159          64159  64159.000000
# unique                            83              9           NaN
# top     Australian Capital Territory          China           NaN
# freq                             773          25509           NaN
# mean                             NaN            NaN     24.537150
# std                              NaN            NaN     28.537223
# min                              NaN            NaN    -51.796300
# 25%                              NaN            NaN     16.742498
# 50%                              NaN            NaN     30.975600
# 75%                              NaN            NaN     44.682000
# max                              NaN            NaN     71.706900
#
#                 Long        Date     Confirmed        Deaths     Recovered  \
# count   64159.000000       64159  6.415900e+04  64159.000000  64159.000000
# unique           NaN         773           NaN           NaN           NaN
# top              NaN  2020-01-22           NaN           NaN           NaN
# freq             NaN          83           NaN           NaN           NaN
# mean       31.341850         NaN  1.750843e+04    305.506866   1186.254041
# std        97.901982         NaN  8.213639e+04   1370.871180   6094.749701
# min      -178.116500         NaN  0.000000e+00      0.000000      0.000000
# 25%       -63.068600         NaN  1.225000e+02      0.000000      0.000000
# 50%        88.092400         NaN  6.180000e+02      3.000000      3.000000
# 75%       116.130600         NaN  2.241000e+03     22.000000    405.000000
# max       165.618042         NaN  1.361680e+06  14056.000000  64435.000000
#
#               Active       WHO Region
# count   6.415900e+04            64159
# unique           NaN                3
# top              NaN  Western Pacific
# freq             NaN            32466
# mean    1.601667e+04              NaN
# std     8.108461e+04              NaN
# min    -8.322000e+03              NaN
# 25%     1.000000e+00              NaN
# 50%     5.500000e+01              NaN
# 75%     1.289000e+03              NaN
# max     1.359744e+06              NaN

# %% [markdown]
# ### 3) Распределение категориальных данных

# %%
for col_categorical in columns_categorical:
    print(f'{data[col_categorical].value_counts()}\n')
# Out:
# Australian Capital Territory    773
# Reunion                         773
# Mayotte                         773
# Martinique                      773
# Guadeloupe                      773
#                                ...
# Guangdong                       773
# Gansu                           773
# Fujian                          773
# Chongqing                       773
# Turks and Caicos Islands        773
# Name: Province/State, Length: 83, dtype: int64
#
# China             25509
# Canada            10049
# United Kingdom     9276
# France             8503
# Australia          6184
# Netherlands        2319
# Denmark             773
# Greenland           773
# New Zealand         773
# Name: Country/Region, dtype: int64
#
# 2020-01-22    83
# 2021-05-20    83
# 2021-06-15    83
# 2021-06-16    83
# 2021-06-17    83
#               ..
# 2020-10-08    83
# 2020-10-09    83
# 2020-10-10    83
# 2020-10-11    83
# 2022-03-04    83
# Name: Date, Length: 773, dtype: int64
#
# Western Pacific    32466
# Europe             21644
# Americas           10049
# Name: WHO Region, dtype: int64
